# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn import metrics
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing

# %%
data = pd.read_csv("data.csv")
#Dataset for breast cancer.

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed:32'],
#       dtype='object')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave_points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
data.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.diagnosis = data.diagnosis.map({'M':1, 'B':0})

# %%
data.diagnosis.unique()
# Out:
# array([1, 0])

# %%
data.drop(['id','Unnamed:32'], inplace=True, axis=1)

# %%
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
data_scaled = pd.DataFrame(preprocessing.scale(data.iloc[:,1:32])) #we are skipping the diagnosis column

# %%
data_scaled.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.097064 -2.073335  1.269934  0.984375  1.568466  3.283515  2.652874
# 1  1.829821 -0.353632  1.685955  1.908708 -0.826962 -0.487072 -0.023846
# 2  1.579888  0.456187  1.566503  1.558884  0.942210  1.052926  1.363478
# 3 -0.768909  0.253732 -0.592687 -0.764464  3.283553  3.402909  1.915897
# 4  1.750297 -1.151816  1.776573  1.826229  0.280372  0.539340  1.371011
#
#          7         8         9     ...           20        21        22  \
# 0  2.532475  2.217515  2.255747    ...     1.886690 -1.359293  2.303601
# 1  0.548144  0.001392 -0.868652    ...     1.805927 -0.369203  1.535126
# 2  2.037231  0.939685 -0.398008    ...     1.511870 -0.023974  1.347475
# 3  1.451707  2.867383  4.910919    ...    -0.281464  0.133984 -0.249939
# 4  1.428493 -0.009560 -0.562450    ...     1.298575 -1.466770  1.338539
#
#          23        24        25        26        27        28        29
# ...

# %%
data_scaled.columns = list(data.iloc[:,1:32].columns)

# %%
data_scaled['diagnosis'] = data['diagnosis']

# %%
data_scaled.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean    ...      texture_worst  perimeter_worst  \
# ...

# %%
data_scaled.describe()
# Out:
#         radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean  -1.256562e-16  1.049736e-16   -1.272171e-16 -1.900452e-16
# std    1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02         5.690000e+02
# mean      1.490704e-16      2.544342e-16   -1.338511e-16        -8.429110e-17
# std       1.000880e+00      1.000880e+00    1.000880e+00         1.000880e+00
# ...

# %%
#looking at the number of patients with Malignant and Benign Tumor

# %%
data_scaled.diagnosis.value_counts().plot(kind='bar', alpha = 0.5, facecolor = 'b', figsize = (12,6))
plt.xticks([0, 1], ["B", "M"])
plt.title("Diagnosis")
# Out:
# Text(0.5,1,'Diagnosis')

# %%
data_scaled.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'diagnosis'],
#       dtype='object')

# %%
data_mean_list = [x for x in data_scaled.columns if 'mean'in x]

# %%
data_mean = data_scaled[data_mean_list]

# %%
data_mean.corr(method="pearson")
# Out:
#                         radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                1.000000      0.323782        0.997855   0.987357
# texture_mean               0.323782      1.000000        0.329533   0.321086
# perimeter_mean             0.997855      0.329533        1.000000   0.986507
# area_mean                  0.987357      0.321086        0.986507   1.000000
# smoothness_mean            0.170581     -0.023389        0.207278   0.177028
# compactness_mean           0.506124      0.236702        0.556936   0.498502
# concavity_mean             0.676764      0.302418        0.716136   0.685983
# concave_points_mean        0.822529      0.293464        0.850977   0.823269
# symmetry_mean              0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean    -0.311631     -0.076437       -0.261477  -0.283110
#
#                         smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
data_mean.corr(method="kendall")
# Out:
#                         radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                1.000000      0.229159        0.963320   0.985565
# texture_mean               0.229159      1.000000        0.234353   0.230829
# perimeter_mean             0.963320      0.234353        1.000000   0.956965
# area_mean                  0.985565      0.230829        0.956965   1.000000
# smoothness_mean            0.099549      0.017135        0.122434   0.092541
# compactness_mean           0.340020      0.184220        0.375540   0.333534
# concavity_mean             0.465087      0.236079        0.497587   0.461843
# concave_points_mean        0.566917      0.209629        0.596716   0.561760
# symmetry_mean              0.081502      0.075493        0.101781   0.076963
# fractal_dimension_mean    -0.246220     -0.039255       -0.214661  -0.252131
#
#                         smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
data_mean.corr(method="spearman")
# Out:
#                         radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                1.000000      0.340956        0.997802   0.999602
# texture_mean               0.340956      1.000000        0.348142   0.344145
# perimeter_mean             0.997802      0.348142        1.000000   0.997068
# area_mean                  0.999602      0.344145        0.997068   1.000000
# smoothness_mean            0.148510      0.024649        0.182923   0.138053
# compactness_mean           0.497578      0.266499        0.543925   0.488988
# concavity_mean             0.645728      0.342646        0.681958   0.642557
# concave_points_mean        0.759702      0.306891        0.788629   0.755165
# symmetry_mean              0.120242      0.110130        0.150049   0.113928
# fractal_dimension_mean    -0.349931     -0.059303       -0.304891  -0.358425
#
#                         smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
plt.figure(figsize=(14,14))
foo = sns.heatmap(data_mean.corr(), vmax=1, square = True, annot = True)

# %%
data_drop_list = ['radius_mean', 'perimeter_mean', 'concave_points_mean']
data_mean.drop(data_drop_list, inplace=True, axis=1)
# Out:
# /Users/hudsonps/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_mean.head()
# Out:
#    texture_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     -2.073335   0.984375         1.568466          3.283515        2.652874
# 1     -0.353632   1.908708        -0.826962         -0.487072       -0.023846
# 2      0.456187   1.558884         0.942210          1.052926        1.363478
# 3      0.253732  -0.764464         3.283553          3.402909        1.915897
# 4     -1.151816   1.826229         0.280372          0.539340        1.371011
#
#    symmetry_mean  fractal_dimension_mean
# 0       2.217515                2.255747
# 1       0.001392               -0.868652
# 2       0.939685               -0.398008
# 3       2.867383                4.910919
# 4      -0.009560               -0.562450

# %%
plt.figure(figsize=(14,14))
foo = sns.heatmap(data_mean.corr(), vmax=1, square = True, annot = True)

# %%
data_mean.diagnosis = data_scaled.diagnosis.copy()

# %%
data_mean.head()
# Out:
#    texture_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     -2.073335   0.984375         1.568466          3.283515        2.652874
# 1     -0.353632   1.908708        -0.826962         -0.487072       -0.023846
# 2      0.456187   1.558884         0.942210          1.052926        1.363478
# 3      0.253732  -0.764464         3.283553          3.402909        1.915897
# 4     -1.151816   1.826229         0.280372          0.539340        1.371011
#
#    symmetry_mean  fractal_dimension_mean
# 0       2.217515                2.255747
# 1       0.001392               -0.868652
# 2       0.939685               -0.398008
# 3       2.867383                4.910919
# 4      -0.009560               -0.562450

# %%
X_train, X_test, y_train, y_test = train_test_split(data_mean, data_scaled['diagnosis'], test_size = 0.2,random_state=0)

# %%
X_train.shape[0]
# Out:
# 455

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
scores = cross_val_score(knn, X_train, y_train, scoring = "accuracy", cv=10).mean()

# %%
print("The mean accuracy with 10-fold cross-validation for KNN is %s" %round(scores*100, 2))
# Out:
# The mean accuracy with 10-fold cross-validation for KNN is 95.37

# %%
from sklearn import tree
dt = tree.DecisionTreeClassifier()
scores = cross_val_score(dt, X_train, y_train, scoring = "accuracy", cv=10).mean()
print("The mean accuracy with 10-fold cross-validation for Decision Tree is %s" %round(scores*100, 2))
# Out:
# The mean accuracy with 10-fold cross-validation for Decision Tree is 90.75

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
scores = cross_val_score(rf, X_train, y_train, scoring = "accuracy", cv=10).mean()
print("The mean accuracy with 10-fold cross validations for Decision Tree is %s" %round(scores*100, 2))
# Out:
# The mean accuracy with 10-fold cross validations for Decision Tree is 93.42

# %%
for ind in range(1,21):
    knn2 = KNeighborsClassifier(n_neighbors = ind)
    scores = cross_val_score(knn2, X_train, y_train, scoring = "accuracy", cv=10).mean()
    print("N = "+ str(ind)+",  score = "+ str(round(scores*100, 2)))
# Out:
# N = 1,  score = 91.86
# N = 2,  score = 92.53
# N = 3,  score = 94.49
# N = 4,  score = 94.71
# N = 5,  score = 95.37
# N = 6,  score = 94.71
# N = 7,  score = 95.37
# N = 8,  score = 94.05
# N = 9,  score = 94.5
# N = 10,  score = 94.05
# N = 11,  score = 94.06
# N = 12,  score = 94.07
# N = 13,  score = 94.07
# N = 14,  score = 93.86
# N = 15,  score = 94.29
# N = 16,  score = 93.86
# N = 17,  score = 93.85
# N = 18,  score = 93.64
# N = 19,  score = 93.86
# N = 20,  score = 94.08

# %%
from sklearn.ensemble import RandomForestClassifier
for ind in range(1,21):
    rf2 = RandomForestClassifier(n_estimators = ind)
    scores = cross_val_score(rf2, X_train, y_train, scoring = "accuracy", cv=10).mean()
    print("N = "+ str(ind)+",  score = "+ str(round(scores*100, 2)))
# Out:
# N = 1,  score = 87.9
# N = 2,  score = 89.69
# N = 3,  score = 89.88
# N = 4,  score = 91.87
# N = 5,  score = 90.8
# N = 6,  score = 92.76
# N = 7,  score = 94.3
# N = 8,  score = 93.85
# N = 9,  score = 92.98
# N = 10,  score = 92.54
# N = 11,  score = 92.98
# N = 12,  score = 92.98
# N = 13,  score = 94.29
# N = 14,  score = 94.28
# N = 15,  score = 93.18
# N = 16,  score = 94.51
# N = 17,  score = 94.52
# N = 18,  score = 94.07
# N = 19,  score = 94.29
# N = 20,  score = 92.75

# %%
rf3 = RandomForestClassifier(n_estimators=17)
rf3 = rf3.fit(X_train, y_train)
predicted = rf3.predict(X_test)
acc_test = metrics.accuracy_score(y_test, predicted)

# %%
print(acc_test)
# Out:
# 0.947368421053

# %%
#Saving a model

# %%
import pickle as pkl
pkl.dump(rf3, open("model1.pkl", "wb"))

# %%
type(rf3)
# Out:
# sklearn.ensemble.forest.RandomForestClassifier

# %%
rf3.predict([np.zeros(7)])
# Out:
# array([0])

# %%
y_train.shape
# Out:
# (455,)
